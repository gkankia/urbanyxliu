# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd

# %%
place = ["Linkoping, Sweden", "Stockholm, Sweden", "Goteborg, Sweden", "Malmo, Sweden", "Umea, Sweden", "Norrkoping, Sweden", "Lund, Sweden", "Uppsala, Sweden"]

# %%
tags = {"amenity": ["atm", "payment_terminal", "bank"]}
gdf = ox.features_from_place(place, tags)
# Out:
# /Users/giorgikankia/anaconda3/lib/python3.10/site-packages/osmnx/_overpass.py:211: UserWarning: This area is 67 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)

# %%
# Convert the GeoDataFrame to a pandas DataFrame
#df = pd.DataFrame(gdf)

# Set the option to display all rows
#pd.set_option("display.max_rows", None)
gdf
# Out:
#                          amenity     brand                   brand:wikipedia  \
# element_type osmid
# node         1669553200      atm  Bankomat                       sv:Bankomat
#              1692398174     bank       NaN                               NaN
#              1692398196     bank  Swedbank                       sv:Swedbank
#              3520104777     bank    Nordea                         sv:Nordea
#              3634146931     bank       SEB  sv:Skandinaviska Enskilda Banken
# ...                          ...       ...                               ...
#              2892247326      atm       NaN                               NaN
#              3173338054      atm       NaN                               NaN
#              5074170119      atm       NaN                               NaN
#              8267083752      atm  Bankomat                       sv:Bankomat
#              11247609478     atm       NaN                               NaN
#
#                          cash_in cash_out currency:SEK drive_through  \
# element_type osmid
# node         1669553200       no      yes          yes            no
#              1692398174      NaN      NaN          NaN           NaN
#              1692398196      NaN      NaN          NaN           NaN
#              3520104777      NaN      NaN          NaN           NaN
#              3634146931      NaN      NaN          NaN           NaN
# ...                          ...      ...          ...           ...
#              2892247326      NaN      NaN          NaN           NaN
#              3173338054      NaN      NaN          NaN           NaN
#              5074170119      NaN      NaN          NaN           NaN
#              8267083752      NaN      NaN          NaN           NaN
#              11247609478      no      NaN          NaN            no
#
#                                                  opening_hours     operator  \
# element_type osmid
# node         1669553200                                   24/7  Bankomat AB
#              1692398174                                    NaN          NaN
#              1692398196                                    NaN          NaN
#              3520104777   Mo-We,Fr 10:00-15:00; Th 10:00-18:00          NaN
#              3634146931                      Mo-Fr 09:00-17:00          NaN
# ...                                                        ...          ...
#              2892247326                                    NaN          NaN
#              3173338054                                    NaN          NaN
#              5074170119                                    NaN          NaN
#              8267083752                                    NaN  Bankomat AB
#              11247609478                                   NaN     Bankomat
#
#                              ref  ... room layer capacity office  \
# element_type osmid                ...
# node         1669553200   304701  ...  NaN   NaN      NaN    NaN
#              1692398174      NaN  ...  NaN   NaN      NaN    NaN
#              1692398196      NaN  ...  NaN   NaN      NaN    NaN
#              3520104777      NaN  ...  NaN   NaN      NaN    NaN
#              3634146931      NaN  ...  NaN   NaN      NaN    NaN
# ...                          ...  ...  ...   ...      ...    ...
#              2892247326      NaN  ...  NaN   NaN      NaN    NaN
#              3173338054      NaN  ...  NaN   NaN      NaN    NaN
#              5074170119      NaN  ...  NaN   NaN      NaN    NaN
#              8267083752      NaN  ...  NaN   NaN      NaN    NaN
#              11247609478     NaN  ...  NaN   NaN      NaN    NaN
#
#                          addr:housename survey:date internet_access  \
# element_type osmid
# node         1669553200             NaN         NaN             NaN
#              1692398174             NaN         NaN             NaN
#              1692398196             NaN         NaN             NaN
#              3520104777             NaN         NaN             NaN
#              3634146931             NaN         NaN             NaN
# ...                                 ...         ...             ...
#              2892247326             NaN         NaN             NaN
#              3173338054             NaN         NaN             NaN
#              5074170119             NaN         NaN             NaN
#              8267083752             NaN         NaN             NaN
#              11247609478            NaN         NaN             NaN
#
#                          payment:cash access contact:email
# element_type osmid
# node         1669553200           NaN    NaN           NaN
#              1692398174           NaN    NaN           NaN
#              1692398196           NaN    NaN           NaN
#              3520104777           NaN    NaN           NaN
#              3634146931           NaN    NaN           NaN
# ...                               ...    ...           ...
#              2892247326           NaN    NaN           NaN
#              3173338054           NaN    NaN           NaN
#              5074170119           NaN    NaN           NaN
#              8267083752           NaN    NaN           NaN
#              11247609478          NaN    NaN           NaN
#
# [489 rows x 59 columns]

# %%
gdf.reset_index([0, 1])
new_gdf = gdf.reset_index(['element_type','osmid'])
new_gdf
# Out:
#     element_type        osmid amenity     brand  \
# 0           node   1669553200     atm  Bankomat
# 1           node   1692398174    bank       NaN
# 2           node   1692398196    bank  Swedbank
# 3           node   3520104777    bank    Nordea
# 4           node   3634146931    bank       SEB
# ..           ...          ...     ...       ...
# 484         node   2892247326     atm       NaN
# 485         node   3173338054     atm       NaN
# 486         node   5074170119     atm       NaN
# 487         node   8267083752     atm  Bankomat
# 488         node  11247609478     atm       NaN
#
#                       brand:wikipedia cash_in cash_out currency:SEK  \
# 0                         sv:Bankomat      no      yes          yes
# 1                                 NaN     NaN      NaN          NaN
# 2                         sv:Swedbank     NaN      NaN          NaN
# 3                           sv:Nordea     NaN      NaN          NaN
# 4    sv:Skandinaviska Enskilda Banken     NaN      NaN          NaN
# ..                                ...     ...      ...          ...
# 484                               NaN     NaN      NaN          NaN
# 485                               NaN     NaN      NaN          NaN
# 486                               NaN     NaN      NaN          NaN
# 487                       sv:Bankomat     NaN      NaN          NaN
# 488                               NaN      no      NaN          NaN
#
#     drive_through                         opening_hours  ... room layer  \
# 0              no                                  24/7  ...  NaN   NaN
# 1             NaN                                   NaN  ...  NaN   NaN
# 2             NaN                                   NaN  ...  NaN   NaN
# 3             NaN  Mo-We,Fr 10:00-15:00; Th 10:00-18:00  ...  NaN   NaN
# 4             NaN                     Mo-Fr 09:00-17:00  ...  NaN   NaN
# ..            ...                                   ...  ...  ...   ...
# 484           NaN                                   NaN  ...  NaN   NaN
# 485           NaN                                   NaN  ...  NaN   NaN
# 486           NaN                                   NaN  ...  NaN   NaN
# 487           NaN                                   NaN  ...  NaN   NaN
# 488            no                                   NaN  ...  NaN   NaN
#
#     capacity office addr:housename survey:date internet_access payment:cash  \
# 0        NaN    NaN            NaN         NaN             NaN          NaN
# 1        NaN    NaN            NaN         NaN             NaN          NaN
# 2        NaN    NaN            NaN         NaN             NaN          NaN
# 3        NaN    NaN            NaN         NaN             NaN          NaN
# 4        NaN    NaN            NaN         NaN             NaN          NaN
# ..       ...    ...            ...         ...             ...          ...
# 484      NaN    NaN            NaN         NaN             NaN          NaN
# 485      NaN    NaN            NaN         NaN             NaN          NaN
# 486      NaN    NaN            NaN         NaN             NaN          NaN
# 487      NaN    NaN            NaN         NaN             NaN          NaN
# 488      NaN    NaN            NaN         NaN             NaN          NaN
#
#     access contact:email
# 0      NaN           NaN
# 1      NaN           NaN
# 2      NaN           NaN
# 3      NaN           NaN
# 4      NaN           NaN
# ..     ...           ...
# 484    NaN           NaN
# 485    NaN           NaN
# 486    NaN           NaN
# 487    NaN           NaN
# 488    NaN           NaN
#
# [489 rows x 61 columns]

# %%
new_gdf.loc[new_gdf['element_type'] == "relation"]

# %%
# Filter the GeoDataFrame to include only nodes, aka points
nodes_gdf = new_gdf[new_gdf['geometry'].type == 'Point']
nodes_gdf
# Out:
#      element_type        osmid entrance                   geometry  \
# 0            node    444845105      NaN  POINT (12.97299 55.61063)
# 1            node    772486928      NaN  POINT (12.97617 55.61406)
# 2            node   1446487347      NaN  POINT (12.92892 55.58213)
# 3            node   1575225594      NaN  POINT (12.97293 55.61276)
# 4            node   1668867727      NaN  POINT (12.98375 55.59378)
# ...           ...          ...      ...                        ...
# 5064         node   9872746482      yes  POINT (11.95027 57.76128)
# 5065         node  10695851958      NaN  POINT (11.92867 57.75059)
# 5066         node  11178620311      NaN  POINT (11.98712 57.85521)
# 5067         node  11247666003      NaN  POINT (11.98924 57.79425)
# 5068         node  11247666005      NaN  POINT (11.98912 57.79425)
#
#          amenity                 name      addr:city addr:country  \
# 0           cafe       Espresso House          Malmö           SE
# 1     restaurant        Torso Twisted          Malmö           SE
# 2     restaurant        Bistro Stella            NaN          NaN
# 3     restaurant              Seaside            NaN          NaN
# 4     restaurant            Bakfickan          Malmö           SE
# ...          ...                  ...            ...          ...
# 5064  restaurant  Pizzeria Casablanca            NaN          NaN
# 5065  restaurant          Double Zero            NaN          NaN
# 5066  restaurant          Rödbo Grill            NaN          NaN
# 5067        cafe             Söta Moa  Hisings Kärra          NaN
# 5068  restaurant  Kärra Pizza & Grill  Hisings Kärra          NaN
#
#      addr:housenumber addr:postcode  ... music charity service:bicycle:repair  \
# 0                  19         21119  ...   NaN     NaN                    NaN
# 1                  44           NaN  ...   NaN     NaN                    NaN
# 2                 NaN           NaN  ...   NaN     NaN                    NaN
# 3                 NaN           NaN  ...   NaN     NaN                    NaN
# 4                  7D         21743  ...   NaN     NaN                    NaN
# ...               ...           ...  ...   ...     ...                    ...
# 5064              NaN           NaN  ...   NaN     NaN                    NaN
# 5065              NaN           NaN  ...   NaN     NaN                    NaN
# 5066              NaN           NaN  ...   NaN     NaN                    NaN
# 5067               10        425 34  ...   NaN     NaN                    NaN
# 5068               11        425 34  ...   NaN     NaN                    NaN
#
#      branch:type dogs architect building:min_level building:roof owner  \
# 0            NaN  NaN       NaN                NaN           NaN   NaN
# 1            NaN  NaN       NaN                NaN           NaN   NaN
# 2            NaN  NaN       NaN                NaN           NaN   NaN
# 3            NaN  NaN       NaN                NaN           NaN   NaN
# 4            NaN  NaN       NaN                NaN           NaN   NaN
# ...          ...  ...       ...                ...           ...   ...
# 5064         NaN  NaN       NaN                NaN           NaN   NaN
# 5065         NaN  NaN       NaN                NaN           NaN   NaN
# 5066         NaN  NaN       NaN                NaN           NaN   NaN
# 5067         NaN  NaN       NaN                NaN           NaN   NaN
# 5068         NaN  NaN       NaN                NaN           NaN   NaN
#
#      pets_allowed
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 5064          NaN
# 5065          NaN
# 5066          NaN
# 5067          NaN
# 5068          NaN
#
# [4788 rows x 262 columns]

# %%
# Define the file path for saving the GeoPackage file
output_file = "/Users/giorgikankia/Documents/GitHub/urbanyxliu/data collection/osm/pois-eatout.geojson"

# Save the filtered GeoDataFrame to a GeoPackage file
nodes_gdf.to_file(output_file, driver='GeoJSON')
