# %%
import osmnx as ox
import geopandas as gpd
import pandas as pd

# %%
place = ["Tbilisi, Georgia", 
         "Batumi, Georgia", 
         "Kutaisi, Georgia", 
         "Zugdidi, Georgia", 
         "Gori, Georgia", 
         "Poti, Georgia",
         "Sokhumi, Georgia",
         "Akhaltsikhe, Georgia"
        ]

# %%
tags = {"amenity": ["cafe", "bar", "restaurant", "nightclub"]}
gdf = ox.features_from_place(place, tags)
gdf
# Out:
#                         addr:housenumber   addr:street     amenity  \
# element_type osmid
# node         1430155787               28  ანგისის ქუჩა  restaurant
#              1430156086              NaN           NaN        cafe
#              4126869099              NaN           NaN  restaurant
#              4256187866              NaN           NaN        cafe
#              4282102591              NaN           NaN        cafe
# ...                                  ...           ...         ...
# way          1195172357              NaN           NaN        cafe
#              1207267295              NaN           NaN  restaurant
#              1207267301              NaN           NaN  restaurant
#              1207543161              NaN           NaN  restaurant
# relation     16055699                NaN           NaN  restaurant
#
#                          check_date      cuisine internet_access  \
# element_type osmid
# node         1430155787  2022-12-04     georgian            wlan
#              1430156086  2023-06-10  coffee_shop             NaN
#              4126869099         NaN          NaN             NaN
#              4256187866         NaN          NaN             NaN
#              4282102591         NaN          NaN             NaN
# ...                             ...          ...             ...
# way          1195172357         NaN          NaN             NaN
#              1207267295         NaN          NaN             NaN
#              1207267301         NaN          NaN             NaN
#              1207543161         NaN          NaN             NaN
# relation     16055699           NaN     regional             NaN
#
#                                           name               name:en  \
# element_type osmid
# node         1430155787            არ დაიდარდო           Ar Daidardo
#              1430156086            Coffee Mark                   NaN
#              4126869099      თურქული რესტორანი                   NaN
#              4256187866                Capitan                   NaN
#              4282102591                    NaN                   NaN
# ...                                        ...                   ...
# way          1195172357                    NaN                   NaN
#              1207267295                    NaN                   NaN
#              1207267301                    NaN                   NaN
#              1207543161                    NaN                   NaN
# relation     16055699    ვარკეთილის ვარსკვლავი  Varketili Varskvlavi
#
#                              name:ka                   source  ...  \
# element_type osmid                                             ...
# node         1430155787  არ დაიდარდო  JumpStart International  ...
#              1430156086          NaN  JumpStart International  ...
#              4126869099          NaN                      NaN  ...
#              4256187866          NaN                      NaN  ...
#              4282102591          NaN                      NaN  ...
# ...                              ...                      ...  ...
# way          1195172357          NaN                      NaN  ...
#              1207267295          NaN                      NaN  ...
#              1207267301          NaN                      NaN  ...
#              1207543161          NaN                      NaN  ...
# relation     16055699            NaN                      NaN  ...
#
#                         payment:visa_debit payment:visa_electron  \
# element_type osmid
# node         1430155787                NaN                   NaN
#              1430156086                NaN                   NaN
#              4126869099                NaN                   NaN
#              4256187866                NaN                   NaN
#              4282102591                NaN                   NaN
# ...                                    ...                   ...
# way          1195172357                NaN                   NaN
#              1207267295                NaN                   NaN
#              1207267301                NaN                   NaN
#              1207543161                NaN                   NaN
# relation     16055699                  NaN                   NaN
#
#                         diet:dairy_free diet:egg_free diet:raw diet:soy_free  \
# element_type osmid
# node         1430155787             NaN           NaN      NaN           NaN
#              1430156086             NaN           NaN      NaN           NaN
#              4126869099             NaN           NaN      NaN           NaN
#              4256187866             NaN           NaN      NaN           NaN
#              4282102591             NaN           NaN      NaN           NaN
# ...                                 ...           ...      ...           ...
# way          1195172357             NaN           NaN      NaN           NaN
#              1207267295             NaN           NaN      NaN           NaN
#              1207267301             NaN           NaN      NaN           NaN
#              1207543161             NaN           NaN      NaN           NaN
# relation     16055699               NaN           NaN      NaN           NaN
#
#                         layer diet:local                     ways  \
# element_type osmid
# node         1430155787   NaN        NaN                      NaN
#              1430156086   NaN        NaN                      NaN
#              4126869099   NaN        NaN                      NaN
#              4256187866   NaN        NaN                      NaN
#              4282102591   NaN        NaN                      NaN
# ...                       ...        ...                      ...
# way          1195172357   NaN        NaN                      NaN
#              1207267295   NaN        NaN                      NaN
#              1207267301   NaN        NaN                      NaN
#              1207543161   NaN        NaN                      NaN
# relation     16055699     NaN        NaN  [936796959, 1187361438]
#
#                                  type
# element_type osmid
# node         1430155787           NaN
#              1430156086           NaN
#              4126869099           NaN
#              4256187866           NaN
#              4282102591           NaN
# ...                               ...
# way          1195172357           NaN
#              1207267295           NaN
#              1207267301           NaN
#              1207543161           NaN
# relation     16055699    multipolygon
#
# [2548 rows x 214 columns]

# %%
gdf.reset_index([0, 1])
new_gdf = gdf.reset_index(['element_type','osmid'])
new_gdf
# Out:
#      element_type       osmid addr:housenumber   addr:street     amenity  \
# 0            node  1430155787               28  ანგისის ქუჩა  restaurant
# 1            node  1430156086              NaN           NaN        cafe
# 2            node  4126869099              NaN           NaN  restaurant
# 3            node  4256187866              NaN           NaN        cafe
# 4            node  4282102591              NaN           NaN        cafe
# ...           ...         ...              ...           ...         ...
# 2543          way  1195172357              NaN           NaN        cafe
# 2544          way  1207267295              NaN           NaN  restaurant
# 2545          way  1207267301              NaN           NaN  restaurant
# 2546          way  1207543161              NaN           NaN  restaurant
# 2547     relation    16055699              NaN           NaN  restaurant
#
#       check_date      cuisine internet_access                   name  \
# 0     2022-12-04     georgian            wlan            არ დაიდარდო
# 1     2023-06-10  coffee_shop             NaN            Coffee Mark
# 2            NaN          NaN             NaN      თურქული რესტორანი
# 3            NaN          NaN             NaN                Capitan
# 4            NaN          NaN             NaN                    NaN
# ...          ...          ...             ...                    ...
# 2543         NaN          NaN             NaN                    NaN
# 2544         NaN          NaN             NaN                    NaN
# 2545         NaN          NaN             NaN                    NaN
# 2546         NaN          NaN             NaN                    NaN
# 2547         NaN     regional             NaN  ვარკეთილის ვარსკვლავი
#
#                    name:en  ... payment:visa_debit payment:visa_electron  \
# 0              Ar Daidardo  ...                NaN                   NaN
# 1                      NaN  ...                NaN                   NaN
# 2                      NaN  ...                NaN                   NaN
# 3                      NaN  ...                NaN                   NaN
# 4                      NaN  ...                NaN                   NaN
# ...                    ...  ...                ...                   ...
# 2543                   NaN  ...                NaN                   NaN
# 2544                   NaN  ...                NaN                   NaN
# 2545                   NaN  ...                NaN                   NaN
# 2546                   NaN  ...                NaN                   NaN
# 2547  Varketili Varskvlavi  ...                NaN                   NaN
#
#      diet:dairy_free diet:egg_free diet:raw diet:soy_free layer diet:local  \
# 0                NaN           NaN      NaN           NaN   NaN        NaN
# 1                NaN           NaN      NaN           NaN   NaN        NaN
# 2                NaN           NaN      NaN           NaN   NaN        NaN
# 3                NaN           NaN      NaN           NaN   NaN        NaN
# 4                NaN           NaN      NaN           NaN   NaN        NaN
# ...              ...           ...      ...           ...   ...        ...
# 2543             NaN           NaN      NaN           NaN   NaN        NaN
# 2544             NaN           NaN      NaN           NaN   NaN        NaN
# 2545             NaN           NaN      NaN           NaN   NaN        NaN
# 2546             NaN           NaN      NaN           NaN   NaN        NaN
# 2547             NaN           NaN      NaN           NaN   NaN        NaN
#
#                          ways          type
# 0                         NaN           NaN
# 1                         NaN           NaN
# 2                         NaN           NaN
# 3                         NaN           NaN
# 4                         NaN           NaN
# ...                       ...           ...
# 2543                      NaN           NaN
# 2544                      NaN           NaN
# 2545                      NaN           NaN
# 2546                      NaN           NaN
# 2547  [936796959, 1187361438]  multipolygon
#
# [2548 rows x 216 columns]

# %%
# Filter the GeoDataFrame to include only nodes, aka points
nodes_gdf = new_gdf[new_gdf['geometry'].type == 'Point']
nodes_gdf
# Out:
#      element_type        osmid addr:housenumber   addr:street     amenity  \
# 0            node   1430155787               28  ანგისის ქუჩა  restaurant
# 1            node   1430156086              NaN           NaN        cafe
# 2            node   4126869099              NaN           NaN  restaurant
# 3            node   4256187866              NaN           NaN        cafe
# 4            node   4282102591              NaN           NaN        cafe
# ...           ...          ...              ...           ...         ...
# 2468         node  11707937869              NaN           NaN        cafe
# 2469         node  11724810514              NaN           NaN         bar
# 2470         node  11724810515              NaN           NaN        cafe
# 2471         node  11724810516              NaN           NaN        cafe
# 2472         node  11727859926              NaN           NaN        cafe
#
#       check_date                 cuisine internet_access               name  \
# 0     2022-12-04                georgian            wlan        არ დაიდარდო
# 1     2023-06-10             coffee_shop             NaN        Coffee Mark
# 2            NaN                     NaN             NaN  თურქული რესტორანი
# 3            NaN                     NaN             NaN            Capitan
# 4            NaN                     NaN             NaN                NaN
# ...          ...                     ...             ...                ...
# 2468         NaN                     NaN             NaN                NaN
# 2469  2024-03-12                     NaN             NaN          Drunk Owl
# 2470  2024-03-12                     NaN             NaN             Conili
# 2471  2024-03-12             coffee_shop             NaN        Coffee dose
# 2472  2024-03-10  italian;french;dessert             NaN            ლე გატო
#
#           name:en  ... payment:visa_debit payment:visa_electron  \
# 0     Ar Daidardo  ...                NaN                   NaN
# 1             NaN  ...                NaN                   NaN
# 2             NaN  ...                NaN                   NaN
# 3             NaN  ...                NaN                   NaN
# 4             NaN  ...                NaN                   NaN
# ...           ...  ...                ...                   ...
# 2468   Slink cafe  ...                NaN                   NaN
# 2469          NaN  ...                NaN                   NaN
# 2470          NaN  ...                NaN                   NaN
# 2471          NaN  ...                NaN                   NaN
# 2472    Le Gâteau  ...                NaN                   NaN
#
#      diet:dairy_free diet:egg_free diet:raw diet:soy_free layer diet:local  \
# 0                NaN           NaN      NaN           NaN   NaN        NaN
# 1                NaN           NaN      NaN           NaN   NaN        NaN
# 2                NaN           NaN      NaN           NaN   NaN        NaN
# 3                NaN           NaN      NaN           NaN   NaN        NaN
# 4                NaN           NaN      NaN           NaN   NaN        NaN
# ...              ...           ...      ...           ...   ...        ...
# 2468             NaN           NaN      NaN           NaN   NaN        NaN
# 2469             NaN           NaN      NaN           NaN   NaN        NaN
# 2470             NaN           NaN      NaN           NaN   NaN        NaN
# 2471             NaN           NaN      NaN           NaN   NaN        NaN
# 2472             NaN           NaN      NaN           NaN   NaN        NaN
#
#      ways type
# 0     NaN  NaN
# 1     NaN  NaN
# 2     NaN  NaN
# 3     NaN  NaN
# 4     NaN  NaN
# ...   ...  ...
# 2468  NaN  NaN
# 2469  NaN  NaN
# 2470  NaN  NaN
# 2471  NaN  NaN
# 2472  NaN  NaN
#
# [2411 rows x 216 columns]

# %%
# Define the file path for saving the GeoPackage file
output_file = "/Users/giorgikankia/Documents/GitHub/Urbanyx Project/data collection/osm/pois-leisure.geojson"

# Save the filtered GeoDataFrame to a GeoPackage file
nodes_gdf.to_file(output_file, driver='GeoJSON')
